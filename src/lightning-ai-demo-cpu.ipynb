# %%
import torch
import torch.nn as nn
import torch.utils.data as data
import torchmetrics
import torchvision as tv

import lightning as L
import matplotlib.pyplot as plt
import numpy as np

print("Using torch", torch.__version__)
print("Using lightning", L.__version__)
# Out:
# Using torch 2.5.0
# Using lightning 2.4.0

# %%
# --------------------
# Load Dataset - MNIST
# --------------------

# dataset: tuple[tensor of shape (N, R, C), label: int]
dataset = tv.datasets.MNIST(root=".", download=True, transform=tv.transforms.ToTensor())
train, val, test = data.random_split(dataset, [55000, 4000, 1000], torch.Generator().manual_seed(42))

# visualize
n = 44
image, label = train[n]
print(f"Number of training samples: {len(train)}")
print(f"Number of validation samples: {len(val)}")
print(f"Number of test samples: {len(test)}")
print(f"Shape of image: {image.shape}")
print(f"Label for this image: {label}")
plt.imshow(image.squeeze(), cmap="gray")
# Out:
# Number of training samples: 55000
# Number of validation samples: 4000
# Number of test samples: 1000
# Shape of image: torch.Size([1, 28, 28])
# Label for this image: 3

# %%
from IPython.display import Image
Image(url="https://www.gabormelli.com/RKB/images/1/19/2NNw.png")
# Out:
# <img src="https://www.gabormelli.com/RKB/images/1/19/2NNw.png"/>

# %%
# ------------
# Create Model
# ------------
class HelloModel(L.LightningModule):
    def __init__(self, hidden_nodes: int = 64):
        super().__init__()
        self.encoder = nn.Sequential(
            nn.Linear(in_features=28 * 28, out_features=hidden_nodes),
            nn.ReLU(),
            nn.Linear(in_features=hidden_nodes, out_features=10),
        )
        self.train_accuracy = torchmetrics.Accuracy(task="multiclass", num_classes=10)
        self.val_accuracy = torchmetrics.Accuracy(task="multiclass", num_classes=10)

    def forward(self, x):
        return self.encoder(x)

    def training_step(self, batch):
        loss = self._step(batch, "train")
        return loss

    def validation_step(self, batch):
        loss = self._step(batch, "val")
        return loss

    def _step(self, batch, step_type):
        images, labels = batch  # images: NxRxC
        n_batch = len(images)
        images = images.view(n_batch, -1)  # images: N x (RxC)
        
        # make predictions
        predictions = self.encoder(images)
        
        loss_fn = nn.CrossEntropyLoss()
        loss = loss_fn(predictions, labels)
        self.log(f"{step_type}_loss", loss)
        
        if step_type == "train":
            self.train_accuracy(predictions, labels)
            self.log(f"{step_type}_accuracy", self.train_accuracy)
        else:
            self.val_accuracy(predictions, labels)
            self.log(f"{step_type}_accuracy", self.val_accuracy)
        return loss

    def configure_optimizers(self):
        optimizer = torch.optim.Adam(self.parameters(), lr=0.001)
        return optimizer

# %%
# -----------
# Train Model
# -----------
model = HelloModel(hidden_nodes=64)

train_dataloader = data.DataLoader(
    dataset=train,
    batch_size=32,
    shuffle=True,
    num_workers=8,
    pin_memory=True,
    persistent_workers=True,
)
val_dataloader = data.DataLoader(
    dataset=val,
    batch_size=64,
    shuffle=False,
    num_workers=8,
    pin_memory=True,
    persistent_workers=True,
)
trainer = L.Trainer(max_epochs=5)
trainer.fit(
    model=model,
    train_dataloaders=train_dataloader,
    val_dataloaders=val_dataloader,
)
# Out:
# GPU available: True (mps), used: True
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
#
#   | Name           | Type               | Params | Mode
# --------------------------------------------------------------
# 0 | encoder        | Sequential         | 50.9 K | train
# 1 | train_accuracy | MulticlassAccuracy | 0      | train
# 2 | val_accuracy   | MulticlassAccuracy | 0      | train
# --------------------------------------------------------------
# 50.9 K    Trainable params
# 0         Non-trainable params
# 50.9 K    Total params
# 0.204     Total estimated model params size (MB)
# 6         Modules in train mode
# 0         Modules in eval mode
# Epoch 0: 100%|██████████| 1719/1719 [00:10<00:00, 162.45it/s, v_num=77]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/63 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/63 [00:00<?, ?it/s]
# Validation DataLoader 0:   2%|▏         | 1/63 [00:00<00:00, 164.42it/s]
# Validation DataLoader 0:   3%|▎         | 2/63 [00:00<00:00, 190.30it/s]
# Validation DataLoader 0:   5%|▍         | 3/63 [00:00<00:00, 201.03it/s]
# Validation DataLoader 0:   6%|▋         | 4/63 [00:00<00:00, 214.74it/s]
# Validation DataLoader 0:   8%|▊         | 5/63 [00:00<00:00, 225.36it/s]
# Validation DataLoader 0:  10%|▉         | 6/63 [00:00<00:00, 230.86it/s]
# Validation DataLoader 0:  11%|█         | 7/63 [00:00<00:00, 236.53it/s]
# Validation DataLoader 0:  13%|█▎        | 8/63 [00:00<00:00, 239.26it/s]
# Validation DataLoader 0:  14%|█▍        | 9/63 [00:00<00:00, 232.56it/s]
# Validation DataLoader 0:  16%|█▌        | 10/63 [00:00<00:00, 235.62it/s]
# Validation DataLoader 0:  17%|█▋        | 11/63 [00:00<00:00, 238.33it/s]
# Validation DataLoader 0:  19%|█▉        | 12/63 [00:00<00:00, 242.14it/s]
# Validation DataLoader 0:  21%|██        | 13/63 [00:00<00:00, 245.45it/s]
# Validation DataLoader 0:  22%|██▏       | 14/63 [00:00<00:00, 248.72it/s]
# Validation DataLoader 0:  24%|██▍       | 15/63 [00:00<00:00, 251.15it/s]
# Validation DataLoader 0:  25%|██▌       | 16/63 [00:00<00:00, 253.04it/s]
# Validation DataLoader 0:  27%|██▋       | 17/63 [00:00<00:00, 255.13it/s]
# Validation DataLoader 0:  29%|██▊       | 18/63 [00:00<00:00, 258.18it/s]
# Validation DataLoader 0:  30%|███       | 19/63 [00:00<00:00, 260.19it/s]
# Validation DataLoader 0:  32%|███▏      | 20/63 [00:00<00:00, 260.54it/s]
# Validation DataLoader 0:  33%|███▎      | 21/63 [00:00<00:00, 261.97it/s]
# Validation DataLoader 0:  35%|███▍      | 22/63 [00:00<00:00, 263.62it/s]
# Validation DataLoader 0:  37%|███▋      | 23/63 [00:00<00:00, 263.96it/s]
# Validation DataLoader 0:  38%|███▊      | 24/63 [00:00<00:00, 264.85it/s]
# Validation DataLoader 0:  40%|███▉      | 25/63 [00:00<00:00, 265.45it/s]
# Validation DataLoader 0:  41%|████▏     | 26/63 [00:00<00:00, 266.18it/s]
# Validation DataLoader 0:  43%|████▎     | 27/63 [00:00<00:00, 266.52it/s]
# Validation DataLoader 0:  44%|████▍     | 28/63 [00:00<00:00, 266.98it/s]
# Validation DataLoader 0:  46%|████▌     | 29/63 [00:00<00:00, 267.91it/s]
# Validation DataLoader 0:  48%|████▊     | 30/63 [00:00<00:00, 268.15it/s]
# Validation DataLoader 0:  49%|████▉     | 31/63 [00:00<00:00, 268.11it/s]
# Validation DataLoader 0:  51%|█████     | 32/63 [00:00<00:00, 268.88it/s]
# Validation DataLoader 0:  52%|█████▏    | 33/63 [00:00<00:00, 268.29it/s]
# Validation DataLoader 0:  54%|█████▍    | 34/63 [00:00<00:00, 268.84it/s]
# Validation DataLoader 0:  56%|█████▌    | 35/63 [00:00<00:00, 269.12it/s]
# Validation DataLoader 0:  57%|█████▋    | 36/63 [00:00<00:00, 268.82it/s]
# Validation DataLoader 0:  59%|█████▊    | 37/63 [00:00<00:00, 268.68it/s]
# Validation DataLoader 0:  60%|██████    | 38/63 [00:00<00:00, 268.41it/s]
# Validation DataLoader 0:  62%|██████▏   | 39/63 [00:00<00:00, 268.72it/s]
# Validation DataLoader 0:  63%|██████▎   | 40/63 [00:00<00:00, 269.60it/s]
# Validation DataLoader 0:  65%|██████▌   | 41/63 [00:00<00:00, 269.20it/s]
# Validation DataLoader 0:  67%|██████▋   | 42/63 [00:00<00:00, 268.58it/s]
# Validation DataLoader 0:  68%|██████▊   | 43/63 [00:00<00:00, 267.81it/s]
# Validation DataLoader 0:  70%|██████▉   | 44/63 [00:00<00:00, 267.43it/s]
# Validation DataLoader 0:  71%|███████▏  | 45/63 [00:00<00:00, 267.55it/s]
# Validation DataLoader 0:  73%|███████▎  | 46/63 [00:00<00:00, 267.90it/s]
# Validation DataLoader 0:  75%|███████▍  | 47/63 [00:00<00:00, 268.59it/s]
# Validation DataLoader 0:  76%|███████▌  | 48/63 [00:00<00:00, 269.23it/s]
# Validation DataLoader 0:  78%|███████▊  | 49/63 [00:00<00:00, 269.84it/s]
# Validation DataLoader 0:  79%|███████▉  | 50/63 [00:00<00:00, 270.71it/s]
# Validation DataLoader 0:  81%|████████  | 51/63 [00:00<00:00, 271.56it/s]
# Validation DataLoader 0:  83%|████████▎ | 52/63 [00:00<00:00, 272.38it/s]
# Validation DataLoader 0:  84%|████████▍ | 53/63 [00:00<00:00, 273.59it/s]
# Validation DataLoader 0:  86%|████████▌ | 54/63 [00:00<00:00, 274.46it/s]
# Validation DataLoader 0:  87%|████████▋ | 55/63 [00:00<00:00, 275.62it/s]
# Validation DataLoader 0:  89%|████████▉ | 56/63 [00:00<00:00, 276.26it/s]
# Validation DataLoader 0:  90%|█████████ | 57/63 [00:00<00:00, 277.00it/s]
# Validation DataLoader 0:  92%|█████████▏| 58/63 [00:00<00:00, 277.89it/s]
# Validation DataLoader 0:  94%|█████████▎| 59/63 [00:00<00:00, 278.24it/s]
# Validation DataLoader 0:  95%|█████████▌| 60/63 [00:00<00:00, 279.14it/s]
# Validation DataLoader 0:  97%|█████████▋| 61/63 [00:00<00:00, 279.66it/s]
# Validation DataLoader 0:  98%|█████████▊| 62/63 [00:00<00:00, 280.48it/s]
# Validation DataLoader 0: 100%|██████████| 63/63 [00:00<00:00, 280.86it/s]
# Epoch 1: 100%|██████████| 1719/1719 [00:07<00:00, 217.39it/s, v_num=77]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/63 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/63 [00:00<?, ?it/s]
# Validation DataLoader 0:   2%|▏         | 1/63 [00:00<00:00, 187.58it/s]
# Validation DataLoader 0:   3%|▎         | 2/63 [00:00<00:00, 207.39it/s]
# Validation DataLoader 0:   5%|▍         | 3/63 [00:00<00:00, 229.04it/s]
# Validation DataLoader 0:   6%|▋         | 4/63 [00:00<00:00, 241.42it/s]
# Validation DataLoader 0:   8%|▊         | 5/63 [00:00<00:00, 245.07it/s]
# Validation DataLoader 0:  10%|▉         | 6/63 [00:00<00:00, 249.43it/s]
# Validation DataLoader 0:  11%|█         | 7/63 [00:00<00:00, 253.78it/s]
# Validation DataLoader 0:  13%|█▎        | 8/63 [00:00<00:00, 254.93it/s]
# Validation DataLoader 0:  14%|█▍        | 9/63 [00:00<00:00, 249.19it/s]
# Validation DataLoader 0:  16%|█▌        | 10/63 [00:00<00:00, 252.69it/s]
# Validation DataLoader 0:  17%|█▋        | 11/63 [00:00<00:00, 255.77it/s]
# Validation DataLoader 0:  19%|█▉        | 12/63 [00:00<00:00, 257.52it/s]
# Validation DataLoader 0:  21%|██        | 13/63 [00:00<00:00, 259.76it/s]
# Validation DataLoader 0:  22%|██▏       | 14/63 [00:00<00:00, 261.04it/s]
# Validation DataLoader 0:  24%|██▍       | 15/63 [00:00<00:00, 262.35it/s]
# Validation DataLoader 0:  25%|██▌       | 16/63 [00:00<00:00, 262.51it/s]
# Validation DataLoader 0:  27%|██▋       | 17/63 [00:00<00:00, 262.59it/s]
# Validation DataLoader 0:  29%|██▊       | 18/63 [00:00<00:00, 263.63it/s]
# Validation DataLoader 0:  30%|███       | 19/63 [00:00<00:00, 263.17it/s]
# Validation DataLoader 0:  32%|███▏      | 20/63 [00:00<00:00, 263.67it/s]
# Validation DataLoader 0:  33%|███▎      | 21/63 [00:00<00:00, 264.82it/s]
# Validation DataLoader 0:  35%|███▍      | 22/63 [00:00<00:00, 264.95it/s]
# Validation DataLoader 0:  37%|███▋      | 23/63 [00:00<00:00, 265.00it/s]
# Validation DataLoader 0:  38%|███▊      | 24/63 [00:00<00:00, 265.17it/s]
# Validation DataLoader 0:  40%|███▉      | 25/63 [00:00<00:00, 265.75it/s]
# Validation DataLoader 0:  41%|████▏     | 26/63 [00:00<00:00, 266.57it/s]
# Validation DataLoader 0:  43%|████▎     | 27/63 [00:00<00:00, 266.34it/s]
# Validation DataLoader 0:  44%|████▍     | 28/63 [00:00<00:00, 266.73it/s]
# Validation DataLoader 0:  46%|████▌     | 29/63 [00:00<00:00, 266.70it/s]
# Validation DataLoader 0:  48%|████▊     | 30/63 [00:00<00:00, 266.58it/s]
# Validation DataLoader 0:  49%|████▉     | 31/63 [00:00<00:00, 266.35it/s]
# Validation DataLoader 0:  51%|█████     | 32/63 [00:00<00:00, 266.93it/s]
# Validation DataLoader 0:  52%|█████▏    | 33/63 [00:00<00:00, 266.94it/s]
# Validation DataLoader 0:  54%|█████▍    | 34/63 [00:00<00:00, 266.66it/s]
# Validation DataLoader 0:  56%|█████▌    | 35/63 [00:00<00:00, 267.26it/s]
# Validation DataLoader 0:  57%|█████▋    | 36/63 [00:00<00:00, 268.01it/s]
# Validation DataLoader 0:  59%|█████▊    | 37/63 [00:00<00:00, 267.71it/s]
# Validation DataLoader 0:  60%|██████    | 38/63 [00:00<00:00, 267.97it/s]
# Validation DataLoader 0:  62%|██████▏   | 39/63 [00:00<00:00, 268.22it/s]
# Validation DataLoader 0:  63%|██████▎   | 40/63 [00:00<00:00, 269.04it/s]
# Validation DataLoader 0:  65%|██████▌   | 41/63 [00:00<00:00, 268.85it/s]
# Validation DataLoader 0:  67%|██████▋   | 42/63 [00:00<00:00, 269.46it/s]
# Validation DataLoader 0:  68%|██████▊   | 43/63 [00:00<00:00, 270.12it/s]
# Validation DataLoader 0:  70%|██████▉   | 44/63 [00:00<00:00, 270.93it/s]
# Validation DataLoader 0:  71%|███████▏  | 45/63 [00:00<00:00, 271.52it/s]
# Validation DataLoader 0:  73%|███████▎  | 46/63 [00:00<00:00, 271.57it/s]
# Validation DataLoader 0:  75%|███████▍  | 47/63 [00:00<00:00, 272.36it/s]
# Validation DataLoader 0:  76%|███████▌  | 48/63 [00:00<00:00, 273.14it/s]
# Validation DataLoader 0:  78%|███████▊  | 49/63 [00:00<00:00, 273.39it/s]
# Validation DataLoader 0:  79%|███████▉  | 50/63 [00:00<00:00, 272.73it/s]
# Validation DataLoader 0:  81%|████████  | 51/63 [00:00<00:00, 273.53it/s]
# Validation DataLoader 0:  83%|████████▎ | 52/63 [00:00<00:00, 274.28it/s]
# Validation DataLoader 0:  84%|████████▍ | 53/63 [00:00<00:00, 274.91it/s]
# Validation DataLoader 0:  86%|████████▌ | 54/63 [00:00<00:00, 275.23it/s]
# Validation DataLoader 0:  87%|████████▋ | 55/63 [00:00<00:00, 275.56it/s]
# Validation DataLoader 0:  89%|████████▉ | 56/63 [00:00<00:00, 276.04it/s]
# Validation DataLoader 0:  90%|█████████ | 57/63 [00:00<00:00, 276.28it/s]
# Validation DataLoader 0:  92%|█████████▏| 58/63 [00:00<00:00, 276.74it/s]
# Validation DataLoader 0:  94%|█████████▎| 59/63 [00:00<00:00, 277.35it/s]
# Validation DataLoader 0:  95%|█████████▌| 60/63 [00:00<00:00, 277.98it/s]
# Validation DataLoader 0:  97%|█████████▋| 61/63 [00:00<00:00, 279.01it/s]
# Validation DataLoader 0:  98%|█████████▊| 62/63 [00:00<00:00, 279.10it/s]
# Validation DataLoader 0: 100%|██████████| 63/63 [00:00<00:00, 278.71it/s]
# Epoch 2: 100%|██████████| 1719/1719 [00:07<00:00, 217.52it/s, v_num=77]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/63 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/63 [00:00<?, ?it/s]
# Validation DataLoader 0:   2%|▏         | 1/63 [00:00<00:00, 185.88it/s]
# Validation DataLoader 0:   3%|▎         | 2/63 [00:00<00:00, 198.24it/s]
# Validation DataLoader 0:   5%|▍         | 3/63 [00:00<00:00, 222.18it/s]
# Validation DataLoader 0:   6%|▋         | 4/63 [00:00<00:00, 235.96it/s]
# Validation DataLoader 0:   8%|▊         | 5/63 [00:00<00:00, 244.39it/s]
# Validation DataLoader 0:  10%|▉         | 6/63 [00:00<00:00, 248.24it/s]
# Validation DataLoader 0:  11%|█         | 7/63 [00:00<00:00, 253.48it/s]
# Validation DataLoader 0:  13%|█▎        | 8/63 [00:00<00:00, 254.92it/s]
# Validation DataLoader 0:  14%|█▍        | 9/63 [00:00<00:00, 254.07it/s]
# Validation DataLoader 0:  16%|█▌        | 10/63 [00:00<00:00, 256.16it/s]
# Validation DataLoader 0:  17%|█▋        | 11/63 [00:00<00:00, 260.55it/s]
# Validation DataLoader 0:  19%|█▉        | 12/63 [00:00<00:00, 264.65it/s]
# Validation DataLoader 0:  21%|██        | 13/63 [00:00<00:00, 265.37it/s]
# Validation DataLoader 0:  22%|██▏       | 14/63 [00:00<00:00, 265.45it/s]
# Validation DataLoader 0:  24%|██▍       | 15/63 [00:00<00:00, 266.45it/s]
# Validation DataLoader 0:  25%|██▌       | 16/63 [00:00<00:00, 267.81it/s]
# Validation DataLoader 0:  27%|██▋       | 17/63 [00:00<00:00, 267.12it/s]
# Validation DataLoader 0:  29%|██▊       | 18/63 [00:00<00:00, 264.91it/s]
# Validation DataLoader 0:  30%|███       | 19/63 [00:00<00:00, 265.44it/s]
# Validation DataLoader 0:  32%|███▏      | 20/63 [00:00<00:00, 266.65it/s]
# Validation DataLoader 0:  33%|███▎      | 21/63 [00:00<00:00, 267.11it/s]
# Validation DataLoader 0:  35%|███▍      | 22/63 [00:00<00:00, 267.17it/s]
# Validation DataLoader 0:  37%|███▋      | 23/63 [00:00<00:00, 267.25it/s]
# Validation DataLoader 0:  38%|███▊      | 24/63 [00:00<00:00, 267.69it/s]
# Validation DataLoader 0:  40%|███▉      | 25/63 [00:00<00:00, 268.50it/s]
# Validation DataLoader 0:  41%|████▏     | 26/63 [00:00<00:00, 268.61it/s]
# Validation DataLoader 0:  43%|████▎     | 27/63 [00:00<00:00, 269.76it/s]
# Validation DataLoader 0:  44%|████▍     | 28/63 [00:00<00:00, 270.61it/s]
# Validation DataLoader 0:  46%|████▌     | 29/63 [00:00<00:00, 270.15it/s]
# Validation DataLoader 0:  48%|████▊     | 30/63 [00:00<00:00, 269.94it/s]
# Validation DataLoader 0:  49%|████▉     | 31/63 [00:00<00:00, 269.95it/s]
# Validation DataLoader 0:  51%|█████     | 32/63 [00:00<00:00, 271.02it/s]
# Validation DataLoader 0:  52%|█████▏    | 33/63 [00:00<00:00, 272.55it/s]
# Validation DataLoader 0:  54%|█████▍    | 34/63 [00:00<00:00, 274.20it/s]
# Validation DataLoader 0:  56%|█████▌    | 35/63 [00:00<00:00, 275.18it/s]
# Validation DataLoader 0:  57%|█████▋    | 36/63 [00:00<00:00, 276.31it/s]
# Validation DataLoader 0:  59%|█████▊    | 37/63 [00:00<00:00, 277.52it/s]
# Validation DataLoader 0:  60%|██████    | 38/63 [00:00<00:00, 278.03it/s]
# Validation DataLoader 0:  62%|██████▏   | 39/63 [00:00<00:00, 279.37it/s]
# Validation DataLoader 0:  63%|██████▎   | 40/63 [00:00<00:00, 279.92it/s]
# Validation DataLoader 0:  65%|██████▌   | 41/63 [00:00<00:00, 280.87it/s]
# Validation DataLoader 0:  67%|██████▋   | 42/63 [00:00<00:00, 281.72it/s]
# Validation DataLoader 0:  68%|██████▊   | 43/63 [00:00<00:00, 282.98it/s]
# Validation DataLoader 0:  70%|██████▉   | 44/63 [00:00<00:00, 283.02it/s]
# Validation DataLoader 0:  71%|███████▏  | 45/63 [00:00<00:00, 284.26it/s]
# Validation DataLoader 0:  73%|███████▎  | 46/63 [00:00<00:00, 284.78it/s]
# Validation DataLoader 0:  75%|███████▍  | 47/63 [00:00<00:00, 284.63it/s]
# Validation DataLoader 0:  76%|███████▌  | 48/63 [00:00<00:00, 284.41it/s]
# Validation DataLoader 0:  78%|███████▊  | 49/63 [00:00<00:00, 284.76it/s]
# Validation DataLoader 0:  79%|███████▉  | 50/63 [00:00<00:00, 284.65it/s]
# Validation DataLoader 0:  81%|████████  | 51/63 [00:00<00:00, 284.91it/s]
# Validation DataLoader 0:  83%|████████▎ | 52/63 [00:00<00:00, 285.21it/s]
# Validation DataLoader 0:  84%|████████▍ | 53/63 [00:00<00:00, 284.68it/s]
# Validation DataLoader 0:  86%|████████▌ | 54/63 [00:00<00:00, 284.84it/s]
# Validation DataLoader 0:  87%|████████▋ | 55/63 [00:00<00:00, 285.21it/s]
# Validation DataLoader 0:  89%|████████▉ | 56/63 [00:00<00:00, 286.06it/s]
# Validation DataLoader 0:  90%|█████████ | 57/63 [00:00<00:00, 286.95it/s]
# Validation DataLoader 0:  92%|█████████▏| 58/63 [00:00<00:00, 287.82it/s]
# Validation DataLoader 0:  94%|█████████▎| 59/63 [00:00<00:00, 288.49it/s]
# Validation DataLoader 0:  95%|█████████▌| 60/63 [00:00<00:00, 288.63it/s]
# Validation DataLoader 0:  97%|█████████▋| 61/63 [00:00<00:00, 289.22it/s]
# Validation DataLoader 0:  98%|█████████▊| 62/63 [00:00<00:00, 289.57it/s]
# Validation DataLoader 0: 100%|██████████| 63/63 [00:00<00:00, 290.43it/s]
# Epoch 3: 100%|██████████| 1719/1719 [00:07<00:00, 222.16it/s, v_num=77]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/63 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/63 [00:00<?, ?it/s]
# Validation DataLoader 0:   2%|▏         | 1/63 [00:00<00:00, 203.42it/s]
# Validation DataLoader 0:   3%|▎         | 2/63 [00:00<00:00, 238.04it/s]
# Validation DataLoader 0:   5%|▍         | 3/63 [00:00<00:00, 254.56it/s]
# Validation DataLoader 0:   6%|▋         | 4/63 [00:00<00:00, 255.44it/s]
# Validation DataLoader 0:   8%|▊         | 5/63 [00:00<00:00, 258.16it/s]
# Validation DataLoader 0:  10%|▉         | 6/63 [00:00<00:00, 260.69it/s]
# Validation DataLoader 0:  11%|█         | 7/63 [00:00<00:00, 264.42it/s]
# Validation DataLoader 0:  13%|█▎        | 8/63 [00:00<00:00, 269.14it/s]
# Validation DataLoader 0:  14%|█▍        | 9/63 [00:00<00:00, 265.66it/s]
# Validation DataLoader 0:  16%|█▌        | 10/63 [00:00<00:00, 262.88it/s]
# Validation DataLoader 0:  17%|█▋        | 11/63 [00:00<00:00, 263.88it/s]
# Validation DataLoader 0:  19%|█▉        | 12/63 [00:00<00:00, 265.86it/s]
# Validation DataLoader 0:  21%|██        | 13/63 [00:00<00:00, 266.66it/s]
# Validation DataLoader 0:  22%|██▏       | 14/63 [00:00<00:00, 268.01it/s]
# Validation DataLoader 0:  24%|██▍       | 15/63 [00:00<00:00, 269.67it/s]
# Validation DataLoader 0:  25%|██▌       | 16/63 [00:00<00:00, 271.69it/s]
# Validation DataLoader 0:  27%|██▋       | 17/63 [00:00<00:00, 271.98it/s]
# Validation DataLoader 0:  29%|██▊       | 18/63 [00:00<00:00, 272.50it/s]
# Validation DataLoader 0:  30%|███       | 19/63 [00:00<00:00, 272.30it/s]
# Validation DataLoader 0:  32%|███▏      | 20/63 [00:00<00:00, 272.66it/s]
# Validation DataLoader 0:  33%|███▎      | 21/63 [00:00<00:00, 272.09it/s]
# Validation DataLoader 0:  35%|███▍      | 22/63 [00:00<00:00, 272.15it/s]
# Validation DataLoader 0:  37%|███▋      | 23/63 [00:00<00:00, 271.70it/s]
# Validation DataLoader 0:  38%|███▊      | 24/63 [00:00<00:00, 271.02it/s]
# Validation DataLoader 0:  40%|███▉      | 25/63 [00:00<00:00, 271.10it/s]
# Validation DataLoader 0:  41%|████▏     | 26/63 [00:00<00:00, 271.90it/s]
# Validation DataLoader 0:  43%|████▎     | 27/63 [00:00<00:00, 271.46it/s]
# Validation DataLoader 0:  44%|████▍     | 28/63 [00:00<00:00, 271.35it/s]
# Validation DataLoader 0:  46%|████▌     | 29/63 [00:00<00:00, 271.26it/s]
# Validation DataLoader 0:  48%|████▊     | 30/63 [00:00<00:00, 271.87it/s]
# Validation DataLoader 0:  49%|████▉     | 31/63 [00:00<00:00, 272.64it/s]
# Validation DataLoader 0:  51%|█████     | 32/63 [00:00<00:00, 272.39it/s]
# Validation DataLoader 0:  52%|█████▏    | 33/63 [00:00<00:00, 273.37it/s]
# Validation DataLoader 0:  54%|█████▍    | 34/63 [00:00<00:00, 274.71it/s]
# Validation DataLoader 0:  56%|█████▌    | 35/63 [00:00<00:00, 274.91it/s]
# Validation DataLoader 0:  57%|█████▋    | 36/63 [00:00<00:00, 275.36it/s]
# Validation DataLoader 0:  59%|█████▊    | 37/63 [00:00<00:00, 276.04it/s]
# Validation DataLoader 0:  60%|██████    | 38/63 [00:00<00:00, 277.12it/s]
# Validation DataLoader 0:  62%|██████▏   | 39/63 [00:00<00:00, 278.01it/s]
# Validation DataLoader 0:  63%|██████▎   | 40/63 [00:00<00:00, 279.09it/s]
# Validation DataLoader 0:  65%|██████▌   | 41/63 [00:00<00:00, 280.31it/s]
# Validation DataLoader 0:  67%|██████▋   | 42/63 [00:00<00:00, 279.66it/s]
# Validation DataLoader 0:  68%|██████▊   | 43/63 [00:00<00:00, 279.60it/s]
# Validation DataLoader 0:  70%|██████▉   | 44/63 [00:00<00:00, 279.43it/s]
# Validation DataLoader 0:  71%|███████▏  | 45/63 [00:00<00:00, 279.14it/s]
# Validation DataLoader 0:  73%|███████▎  | 46/63 [00:00<00:00, 279.07it/s]
# Validation DataLoader 0:  75%|███████▍  | 47/63 [00:00<00:00, 279.61it/s]
# Validation DataLoader 0:  76%|███████▌  | 48/63 [00:00<00:00, 280.48it/s]
# Validation DataLoader 0:  78%|███████▊  | 49/63 [00:00<00:00, 281.26it/s]
# Validation DataLoader 0:  79%|███████▉  | 50/63 [00:00<00:00, 282.12it/s]
# Validation DataLoader 0:  81%|████████  | 51/63 [00:00<00:00, 282.16it/s]
# Validation DataLoader 0:  83%|████████▎ | 52/63 [00:00<00:00, 282.06it/s]
# Validation DataLoader 0:  84%|████████▍ | 53/63 [00:00<00:00, 282.28it/s]
# Validation DataLoader 0:  86%|████████▌ | 54/63 [00:00<00:00, 283.23it/s]
# Validation DataLoader 0:  87%|████████▋ | 55/63 [00:00<00:00, 284.06it/s]
# Validation DataLoader 0:  89%|████████▉ | 56/63 [00:00<00:00, 284.52it/s]
# Validation DataLoader 0:  90%|█████████ | 57/63 [00:00<00:00, 284.53it/s]
# Validation DataLoader 0:  92%|█████████▏| 58/63 [00:00<00:00, 284.68it/s]
# Validation DataLoader 0:  94%|█████████▎| 59/63 [00:00<00:00, 284.07it/s]
# Validation DataLoader 0:  95%|█████████▌| 60/63 [00:00<00:00, 284.38it/s]
# Validation DataLoader 0:  97%|█████████▋| 61/63 [00:00<00:00, 284.61it/s]
# Validation DataLoader 0:  98%|█████████▊| 62/63 [00:00<00:00, 285.10it/s]
# Validation DataLoader 0: 100%|██████████| 63/63 [00:00<00:00, 285.09it/s]
# Epoch 4: 100%|██████████| 1719/1719 [00:07<00:00, 216.81it/s, v_num=77]
# Validation: |          | 0/? [00:00<?, ?it/s]
# Validation:   0%|          | 0/63 [00:00<?, ?it/s]
# Validation DataLoader 0:   0%|          | 0/63 [00:00<?, ?it/s]
# Validation DataLoader 0:   2%|▏         | 1/63 [00:00<00:00, 218.72it/s]
# Validation DataLoader 0:   3%|▎         | 2/63 [00:00<00:00, 239.28it/s]
# Validation DataLoader 0:   5%|▍         | 3/63 [00:00<00:00, 249.46it/s]
# Validation DataLoader 0:   6%|▋         | 4/63 [00:00<00:00, 255.16it/s]
# Validation DataLoader 0:   8%|▊         | 5/63 [00:00<00:00, 258.25it/s]
# Validation DataLoader 0:  10%|▉         | 6/63 [00:00<00:00, 264.54it/s]
# Validation DataLoader 0:  11%|█         | 7/63 [00:00<00:00, 268.81it/s]
# Validation DataLoader 0:  13%|█▎        | 8/63 [00:00<00:00, 270.78it/s]
# Validation DataLoader 0:  14%|█▍        | 9/63 [00:00<00:00, 263.82it/s]
# Validation DataLoader 0:  16%|█▌        | 10/63 [00:00<00:00, 264.35it/s]
# Validation DataLoader 0:  17%|█▋        | 11/63 [00:00<00:00, 262.64it/s]
# Validation DataLoader 0:  19%|█▉        | 12/63 [00:00<00:00, 264.05it/s]
# Validation DataLoader 0:  21%|██        | 13/63 [00:00<00:00, 267.10it/s]
# Validation DataLoader 0:  22%|██▏       | 14/63 [00:00<00:00, 268.27it/s]
# Validation DataLoader 0:  24%|██▍       | 15/63 [00:00<00:00, 270.14it/s]
# Validation DataLoader 0:  25%|██▌       | 16/63 [00:00<00:00, 270.35it/s]
# Validation DataLoader 0:  27%|██▋       | 17/63 [00:00<00:00, 270.48it/s]
# Validation DataLoader 0:  29%|██▊       | 18/63 [00:00<00:00, 269.94it/s]
# Validation DataLoader 0:  30%|███       | 19/63 [00:00<00:00, 270.09it/s]
# Validation DataLoader 0:  32%|███▏      | 20/63 [00:00<00:00, 270.03it/s]
# Validation DataLoader 0:  33%|███▎      | 21/63 [00:00<00:00, 270.39it/s]
# Validation DataLoader 0:  35%|███▍      | 22/63 [00:00<00:00, 269.42it/s]
# Validation DataLoader 0:  37%|███▋      | 23/63 [00:00<00:00, 269.30it/s]
# Validation DataLoader 0:  38%|███▊      | 24/63 [00:00<00:00, 269.25it/s]
# Validation DataLoader 0:  40%|███▉      | 25/63 [00:00<00:00, 269.73it/s]
# Validation DataLoader 0:  41%|████▏     | 26/63 [00:00<00:00, 270.44it/s]
# Validation DataLoader 0:  43%|████▎     | 27/63 [00:00<00:00, 270.95it/s]
# Validation DataLoader 0:  44%|████▍     | 28/63 [00:00<00:00, 270.83it/s]
# Validation DataLoader 0:  46%|████▌     | 29/63 [00:00<00:00, 271.28it/s]
# Validation DataLoader 0:  48%|████▊     | 30/63 [00:00<00:00, 271.06it/s]
# Validation DataLoader 0:  49%|████▉     | 31/63 [00:00<00:00, 271.41it/s]
# Validation DataLoader 0:  51%|█████     | 32/63 [00:00<00:00, 271.74it/s]
# Validation DataLoader 0:  52%|█████▏    | 33/63 [00:00<00:00, 272.82it/s]
# Validation DataLoader 0:  54%|█████▍    | 34/63 [00:00<00:00, 273.44it/s]
# Validation DataLoader 0:  56%|█████▌    | 35/63 [00:00<00:00, 274.51it/s]
# Validation DataLoader 0:  57%|█████▋    | 36/63 [00:00<00:00, 275.32it/s]
# Validation DataLoader 0:  59%|█████▊    | 37/63 [00:00<00:00, 276.53it/s]
# Validation DataLoader 0:  60%|██████    | 38/63 [00:00<00:00, 277.41it/s]
# Validation DataLoader 0:  62%|██████▏   | 39/63 [00:00<00:00, 277.44it/s]
# Validation DataLoader 0:  63%|██████▎   | 40/63 [00:00<00:00, 278.02it/s]
# Validation DataLoader 0:  65%|██████▌   | 41/63 [00:00<00:00, 278.49it/s]
# Validation DataLoader 0:  67%|██████▋   | 42/63 [00:00<00:00, 278.72it/s]
# Validation DataLoader 0:  68%|██████▊   | 43/63 [00:00<00:00, 278.69it/s]
# Validation DataLoader 0:  70%|██████▉   | 44/63 [00:00<00:00, 279.21it/s]
# Validation DataLoader 0:  71%|███████▏  | 45/63 [00:00<00:00, 280.30it/s]
# Validation DataLoader 0:  73%|███████▎  | 46/63 [00:00<00:00, 281.04it/s]
# Validation DataLoader 0:  75%|███████▍  | 47/63 [00:00<00:00, 280.76it/s]
# Validation DataLoader 0:  76%|███████▌  | 48/63 [00:00<00:00, 280.77it/s]
# Validation DataLoader 0:  78%|███████▊  | 49/63 [00:00<00:00, 280.68it/s]
# Validation DataLoader 0:  79%|███████▉  | 50/63 [00:00<00:00, 281.12it/s]
# Validation DataLoader 0:  81%|████████  | 51/63 [00:00<00:00, 281.90it/s]
# Validation DataLoader 0:  83%|████████▎ | 52/63 [00:00<00:00, 282.52it/s]
# Validation DataLoader 0:  84%|████████▍ | 53/63 [00:00<00:00, 283.62it/s]
# Validation DataLoader 0:  86%|████████▌ | 54/63 [00:00<00:00, 284.71it/s]
# Validation DataLoader 0:  87%|████████▋ | 55/63 [00:00<00:00, 285.40it/s]
# Validation DataLoader 0:  89%|████████▉ | 56/63 [00:00<00:00, 285.47it/s]
# Validation DataLoader 0:  90%|█████████ | 57/63 [00:00<00:00, 285.98it/s]
# Validation DataLoader 0:  92%|█████████▏| 58/63 [00:00<00:00, 285.88it/s]
# Validation DataLoader 0:  94%|█████████▎| 59/63 [00:00<00:00, 286.12it/s]
# Validation DataLoader 0:  95%|█████████▌| 60/63 [00:00<00:00, 286.37it/s]
# Validation DataLoader 0:  97%|█████████▋| 61/63 [00:00<00:00, 286.94it/s]
# Validation DataLoader 0:  98%|█████████▊| 62/63 [00:00<00:00, 287.60it/s]
# Validation DataLoader 0: 100%|██████████| 63/63 [00:00<00:00, 288.31it/s]
# Epoch 4: 100%|██████████| 1719/1719 [00:08<00:00, 210.68it/s, v_num=77]
# `Trainer.fit` stopped: `max_epochs=5` reached.
# Epoch 4: 100%|██████████| 1719/1719 [00:08<00:00, 210.55it/s, v_num=77]

# %%
# -------------
# Run Inference
# -------------
for n in [53, 54, 55]:
    image, label = test[n]
    image_view = image.view(1, -1)
    softmax = nn.Softmax(dim=1)
    pred = softmax(model(image_view)).detach().numpy().squeeze()
    # show
    plt.figure()
    plt.imshow(image.squeeze(), cmap="gray")
    print(label)
    print(["{0}:{1:.3%}".format(i, prob) for i, prob in enumerate(pred)])
# Out:
# 6
# ['0:0.000%', '1:0.000%', '2:0.000%', '3:0.000%', '4:0.000%', '5:0.000%', '6:100.000%', '7:0.000%', '8:0.000%', '9:0.000%']
# 8
# ['0:0.008%', '1:0.039%', '2:0.031%', '3:0.623%', '4:1.913%', '5:0.009%', '6:0.000%', '7:62.214%', '8:25.922%', '9:9.240%']
# 8
# ['0:0.001%', '1:1.934%', '2:0.020%', '3:0.545%', '4:0.000%', '5:0.020%', '6:0.000%', '7:0.308%', '8:97.132%', '9:0.038%']

# %%
# tensorboard --logdir .
